# %%
import numpy as np
import pandas as pd
import os
import sys

# %%
WHITE_list = np.array([14, 15, 20, 21, 23, 29, 31, 32, 34, 36, 38, 40, 42, 45, 47, 48, 64, 69, 79, 80, 82, 85, 86, 91, 92, 95, 97])
ASIAN_list = np.array([5, 7, 13, 24, 25, 27, 35, 37, 43, 44, 46, 49, 51, 52, 54, 55, 56, 57, 61, 63, 65, 68, 71, 72, 73, 74, 75, 76, 81, 84, 93, 94])
URG_list = np.array([22, 70, 78, 28, 60, 58])


print('WHITE_list size: {}'.format(len(WHITE_list)))
print('ASIAN_list size: {}'.format(len(ASIAN_list)))
print('URG_list size: {}'.format(len(URG_list)))
# Out:
# WHITE_list size: 27
# ASIAN_list size: 32
# URG_list size: 6

# %% [markdown]
# ### RandomForest

# %% [markdown]
# ### seed2

# %%
root_path = '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_models/WhiteSubset/RandomForest/binary/'

# %%
scenario_21vs6_summary_path = '21vs6/seed2_summary'

# %%
scenario_21vs4_df = pd.read_csv(os.path.join(root_path, scenario_21vs6_summary_path, 'AllSubjects_summary.csv'))

# %%
scenario_21vs4_WHITE_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(WHITE_list)]
scenario_21vs4_ASIAN_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(ASIAN_list)]
scenario_21vs4_URG_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(URG_list)]

# %%
scenario_21vs4_WHITE_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 0           69                   71.022                    88.709677
# 2           80                   71.022                    59.946237
# 7           97                   71.022                    74.462366
# 8           92                   71.022                    81.989247
# 12          64                   71.022                    75.000000
# 17          15                   71.022                    98.655914
#
#                                    performance_string  \
# 0   highest validation accuracy: 71.02150537634408...
# 2   highest validation accuracy: 71.02150537634408...
# 7   highest validation accuracy: 71.02150537634408...
# 8   highest validation accuracy: 71.02150537634408...
# 12  highest validation accuracy: 71.02150537634408...
# 17  highest validation accuracy: 71.02150537634408...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_ASIAN_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 1           37                   71.022                    50.537634
# 3            7                   71.022                    92.741935
# 4           24                   71.022                    72.580645
# 11          94                   71.022                    68.817204
# 13          54                   71.022                    67.473118
# 15          25                   71.022                    56.989247
#
#                                    performance_string  \
# 1   highest validation accuracy: 71.02150537634408...
# 3   highest validation accuracy: 71.02150537634408...
# 4   highest validation accuracy: 71.02150537634408...
# 11  highest validation accuracy: 71.02150537634408...
# 13  highest validation accuracy: 71.02150537634408...
# 15  highest validation accuracy: 71.02150537634408...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_URG_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 5           70                   71.022                    55.913978
# 6           78                   71.022                    90.053763
# 9           60                   71.022                    70.161290
# 10          58                   71.022                    57.258065
# 14          22                   71.022                    78.494624
# 16          28                   71.022                    77.419355
#
#                                    performance_string  \
# 5   highest validation accuracy: 71.02150537634408...
# 6   highest validation accuracy: 71.02150537634408...
# 9   highest validation accuracy: 71.02150537634408...
# 10  highest validation accuracy: 71.02150537634408...
# 14  highest validation accuracy: 71.02150537634408...
# 16  highest validation accuracy: 71.02150537634408...
#
#                                     experiment_folder
# ...

# %%
print('RF, Binary, Average Accuracy:')
print('WHITE: {}'.format(np.mean(scenario_21vs4_WHITE_df.corresponding_test_accuracy.values)))
print('ASIAN: {}'.format(np.mean(scenario_21vs4_ASIAN_df.corresponding_test_accuracy.values)))
print('URG: {}'.format(np.mean(scenario_21vs4_URG_df.corresponding_test_accuracy.values)))
# Out:
# RF, Binary, Average Accuracy:
# WHITE: 79.79390681003584
# ASIAN: 68.18996415770609
# URG: 71.55017921146954

# %% [markdown]
# ### seed3

# %%
root_path = '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_models/WhiteSubset/RandomForest/binary/'

# %%
scenario_21vs6_summary_path = '21vs6/seed3_summary'

# %%
scenario_21vs4_df = pd.read_csv(os.path.join(root_path, scenario_21vs6_summary_path, 'AllSubjects_summary.csv'))

# %%
scenario_21vs4_WHITE_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(WHITE_list)]
scenario_21vs4_ASIAN_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(ASIAN_list)]
scenario_21vs4_URG_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(URG_list)]

# %%
scenario_21vs4_WHITE_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 0           34                    61.64                    81.989247
# 1           85                    61.64                    96.774194
# 7           36                    61.64                    70.698925
# 8           82                    61.64                    54.301075
# 11          29                    61.64                    72.311828
# 14          20                    61.64                    84.408602
#
#                                    performance_string  \
# 0   highest validation accuracy: 61.63978494623657...
# 1   highest validation accuracy: 61.63978494623657...
# 7   highest validation accuracy: 61.63978494623657...
# 8   highest validation accuracy: 61.63978494623657...
# 11  highest validation accuracy: 61.63978494623657...
# 14  highest validation accuracy: 61.63978494623657...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_ASIAN_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 2           56                    61.64                    94.892473
# 3           24                    61.64                    88.978495
# 9           55                    61.64                    91.397849
# 12          13                    61.64                    60.752688
# 16          76                    61.64                    66.397849
# 17          93                    61.64                    55.913978
#
#                                    performance_string  \
# 2   highest validation accuracy: 61.63978494623657...
# 3   highest validation accuracy: 61.63978494623657...
# 9   highest validation accuracy: 61.63978494623657...
# 12  highest validation accuracy: 61.63978494623657...
# 16  highest validation accuracy: 61.63978494623657...
# 17  highest validation accuracy: 61.63978494623657...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_URG_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 4           70                    61.64                    68.548387
# 5           78                    61.64                    92.204301
# 6           60                    61.64                    78.763441
# 10          58                    61.64                    49.731183
# 13          22                    61.64                    76.881720
# 15          28                    61.64                    63.978495
#
#                                    performance_string  \
# 4   highest validation accuracy: 61.63978494623657...
# 5   highest validation accuracy: 61.63978494623657...
# 6   highest validation accuracy: 61.63978494623657...
# 10  highest validation accuracy: 61.63978494623657...
# 13  highest validation accuracy: 61.63978494623657...
# 15  highest validation accuracy: 61.63978494623657...
#
#                                     experiment_folder
# ...

# %%
print('RF, Binary, Average Accuracy:')
print('WHITE: {}'.format(np.mean(scenario_21vs4_WHITE_df.corresponding_test_accuracy.values)))
print('ASIAN: {}'.format(np.mean(scenario_21vs4_ASIAN_df.corresponding_test_accuracy.values)))
print('URG: {}'.format(np.mean(scenario_21vs4_URG_df.corresponding_test_accuracy.values)))
# Out:
# RF, Binary, Average Accuracy:
# WHITE: 76.74731182795698
# ASIAN: 76.38888888888887
# URG: 71.68458781362007

# %% [markdown]
# ### seed5

# %%
root_path = '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_models/WhiteSubset/RandomForest/binary/'

# %%
scenario_21vs6_summary_path = '21vs6/seed5_summary'

# %%
scenario_21vs4_df = pd.read_csv(os.path.join(root_path, scenario_21vs6_summary_path, 'AllSubjects_summary.csv'))

# %%
scenario_21vs4_WHITE_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(WHITE_list)]
scenario_21vs4_ASIAN_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(ASIAN_list)]
scenario_21vs4_URG_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(URG_list)]

# %%
scenario_21vs4_WHITE_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 0           69                    60.78                    91.397849
# 1           34                    60.78                    73.655914
# 8           97                    60.78                    86.021505
# 11          86                    60.78                    75.000000
# 14          20                    60.78                    86.559140
# 16          79                    60.78                    56.989247
#
#                                    performance_string  \
# 0   highest validation accuracy: 60.77956989247312...
# 1   highest validation accuracy: 60.77956989247312...
# 8   highest validation accuracy: 60.77956989247312...
# 11  highest validation accuracy: 60.77956989247312...
# 14  highest validation accuracy: 60.77956989247312...
# 16  highest validation accuracy: 60.77956989247312...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_ASIAN_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 2            7                    60.78                    75.000000
# 3           56                    60.78                   100.000000
# 6           43                    60.78                    81.720430
# 7           49                    60.78                    80.913978
# 12          57                    60.78                    85.483871
# 17          61                    60.78                    57.526882
#
#                                    performance_string  \
# 2   highest validation accuracy: 60.77956989247312...
# 3   highest validation accuracy: 60.77956989247312...
# 6   highest validation accuracy: 60.77956989247312...
# 7   highest validation accuracy: 60.77956989247312...
# 12  highest validation accuracy: 60.77956989247312...
# 17  highest validation accuracy: 60.77956989247312...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_URG_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 4           70                    60.78                    69.892473
# 5           78                    60.78                    95.430108
# 9           60                    60.78                    80.645161
# 10          58                    60.78                    52.956989
# 13          22                    60.78                    86.559140
# 15          28                    60.78                    71.505376
#
#                                    performance_string  \
# 4   highest validation accuracy: 60.77956989247312...
# 5   highest validation accuracy: 60.77956989247312...
# 9   highest validation accuracy: 60.77956989247312...
# 10  highest validation accuracy: 60.77956989247312...
# 13  highest validation accuracy: 60.77956989247312...
# 15  highest validation accuracy: 60.77956989247312...
#
#                                     experiment_folder
# ...

# %%
print('RF, Binary, Average Accuracy:')
print('WHITE: {}'.format(np.mean(scenario_21vs4_WHITE_df.corresponding_test_accuracy.values)))
print('ASIAN: {}'.format(np.mean(scenario_21vs4_ASIAN_df.corresponding_test_accuracy.values)))
print('URG: {}'.format(np.mean(scenario_21vs4_URG_df.corresponding_test_accuracy.values)))
# Out:
# RF, Binary, Average Accuracy:
# WHITE: 78.2706093189964
# ASIAN: 80.10752688172043
# URG: 76.16487455197132

# %% [markdown]
# ### seed7

# %%
root_path = '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_models/WhiteSubset/RandomForest/binary/'

# %%
scenario_21vs6_summary_path = '21vs6/seed7_summary'

# %%
scenario_21vs4_df = pd.read_csv(os.path.join(root_path, scenario_21vs6_summary_path, 'AllSubjects_summary.csv'))

# %%
scenario_21vs4_WHITE_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(WHITE_list)]
scenario_21vs4_ASIAN_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(ASIAN_list)]
scenario_21vs4_URG_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(URG_list)]

# %%
scenario_21vs4_WHITE_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 0           69                   76.048                    77.956989
# 1           34                   76.048                    82.526882
# 2           85                   76.048                    92.204301
# 9           31                   76.048                    62.903226
# 11          32                   76.048                    84.677419
# 12          86                   76.048                    49.462366
#
#                                    performance_string  \
# 0   highest validation accuracy: 76.04838709677419...
# 1   highest validation accuracy: 76.04838709677419...
# 2   highest validation accuracy: 76.04838709677419...
# 9   highest validation accuracy: 76.04838709677419...
# 11  highest validation accuracy: 76.04838709677419...
# 12  highest validation accuracy: 76.04838709677419...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_ASIAN_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 3           56                   76.048                    94.623656
# 4           51                   76.048                    74.462366
# 7           65                   76.048                    72.043011
# 13          52                   76.048                    62.365591
# 15          25                   76.048                    55.645161
# 17          44                   76.048                    73.118280
#
#                                    performance_string  \
# 3   highest validation accuracy: 76.04838709677419...
# 4   highest validation accuracy: 76.04838709677419...
# 7   highest validation accuracy: 76.04838709677419...
# 13  highest validation accuracy: 76.04838709677419...
# 15  highest validation accuracy: 76.04838709677419...
# 17  highest validation accuracy: 76.04838709677419...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_URG_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 5           70                   76.048                    61.827957
# 6           78                   76.048                    87.634409
# 8           60                   76.048                    44.892473
# 10          58                   76.048                    55.913978
# 14          22                   76.048                    68.548387
# 16          28                   76.048                    79.032258
#
#                                    performance_string  \
# 5   highest validation accuracy: 76.04838709677419...
# 6   highest validation accuracy: 76.04838709677419...
# 8   highest validation accuracy: 76.04838709677419...
# 10  highest validation accuracy: 76.04838709677419...
# 14  highest validation accuracy: 76.04838709677419...
# 16  highest validation accuracy: 76.04838709677419...
#
#                                     experiment_folder
# ...

# %%
print('RF, Binary, Average Accuracy:')
print('WHITE: {}'.format(np.mean(scenario_21vs4_WHITE_df.corresponding_test_accuracy.values)))
print('ASIAN: {}'.format(np.mean(scenario_21vs4_ASIAN_df.corresponding_test_accuracy.values)))
print('URG: {}'.format(np.mean(scenario_21vs4_URG_df.corresponding_test_accuracy.values)))
# Out:
# RF, Binary, Average Accuracy:
# WHITE: 74.95519713261649
# ASIAN: 72.04301075268818
# URG: 66.30824372759857

# %% [markdown]
# ### EEGNet

# %% [markdown]
# ### seed2

# %%
root_path = '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_models/WhiteSubset/EEGNet/binary/'

# %%
scenario_21vs6_summary_path = '21vs6/seed2_summary'

# %%
scenario_21vs4_df = pd.read_csv(os.path.join(root_path, scenario_21vs6_summary_path, 'AllSubjects_summary.csv'))

# %%
scenario_21vs4_WHITE_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(WHITE_list)]
scenario_21vs4_ASIAN_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(ASIAN_list)]
scenario_21vs4_URG_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(URG_list)]

# %%
scenario_21vs4_WHITE_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 0           69                   77.984                    72.311828
# 2           80                   77.984                    48.924731
# 7           97                   77.984                    59.946237
# 8           92                   77.984                    83.870968
# 12          64                   77.984                    83.333333
# 17          15                   77.984                    93.010753
#
#                                    performance_string  \
# 0   highest validation accuracy: 77.98387096774194...
# 2   highest validation accuracy: 77.98387096774194...
# 7   highest validation accuracy: 77.98387096774194...
# 8   highest validation accuracy: 77.98387096774194...
# 12  highest validation accuracy: 77.98387096774194...
# 17  highest validation accuracy: 77.98387096774194...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_ASIAN_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 1           37                   77.984                    47.043011
# 3            7                   77.984                    62.365591
# 4           24                   77.984                    38.978495
# 11          94                   77.984                    75.537634
# 13          54                   77.984                    83.064516
# 15          25                   77.984                    78.494624
#
#                                    performance_string  \
# 1   highest validation accuracy: 77.98387096774194...
# 3   highest validation accuracy: 77.98387096774194...
# 4   highest validation accuracy: 77.98387096774194...
# 11  highest validation accuracy: 77.98387096774194...
# 13  highest validation accuracy: 77.98387096774194...
# 15  highest validation accuracy: 77.98387096774194...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_URG_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 5           70                   77.984                    71.505376
# 6           78                   77.984                    72.311828
# 9           60                   77.984                    28.494624
# 10          58                   77.984                    50.000000
# 14          22                   77.984                    85.483871
# 16          28                   77.984                    67.204301
#
#                                    performance_string  \
# 5   highest validation accuracy: 77.98387096774194...
# 6   highest validation accuracy: 77.98387096774194...
# 9   highest validation accuracy: 77.98387096774194...
# 10  highest validation accuracy: 77.98387096774194...
# 14  highest validation accuracy: 77.98387096774194...
# 16  highest validation accuracy: 77.98387096774194...
#
#                                     experiment_folder
# ...

# %%
print('RF, Binary, Average Accuracy:')
print('WHITE: {}'.format(np.mean(scenario_21vs4_WHITE_df.corresponding_test_accuracy.values)))
print('ASIAN: {}'.format(np.mean(scenario_21vs4_ASIAN_df.corresponding_test_accuracy.values)))
print('URG: {}'.format(np.mean(scenario_21vs4_URG_df.corresponding_test_accuracy.values)))
# Out:
# RF, Binary, Average Accuracy:
# WHITE: 73.56630824372759
# ASIAN: 64.24731182795699
# URG: 62.5

# %% [markdown]
# ### seed3

# %%
root_path = '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_models/WhiteSubset/EEGNet/binary/'

# %%
scenario_21vs6_summary_path = '21vs6/seed3_summary'

# %%
scenario_21vs4_df = pd.read_csv(os.path.join(root_path, scenario_21vs6_summary_path, 'AllSubjects_summary.csv'))

# %%
scenario_21vs4_WHITE_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(WHITE_list)]
scenario_21vs4_ASIAN_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(ASIAN_list)]
scenario_21vs4_URG_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(URG_list)]

# %%
scenario_21vs4_WHITE_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 0           34                   68.199                    62.365591
# 1           85                   68.199                    66.935484
# 7           36                   68.199                    53.225806
# 8           82                   68.199                    23.924731
# 11          29                   68.199                    68.010753
# 14          20                   68.199                    97.043011
#
#                                    performance_string  \
# 0   highest validation accuracy: 68.1989247311828\...
# 1   highest validation accuracy: 68.1989247311828\...
# 7   highest validation accuracy: 68.1989247311828\...
# 8   highest validation accuracy: 68.1989247311828\...
# 11  highest validation accuracy: 68.1989247311828\...
# 14  highest validation accuracy: 68.1989247311828\...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_ASIAN_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 2           56                   68.199                    70.430108
# 3           24                   68.199                    47.580645
# 9           55                   68.199                    44.086022
# 12          13                   68.199                    32.795699
# 16          76                   68.199                    56.451613
# 17          93                   68.199                    65.053763
#
#                                    performance_string  \
# 2   highest validation accuracy: 68.1989247311828\...
# 3   highest validation accuracy: 68.1989247311828\...
# 9   highest validation accuracy: 68.1989247311828\...
# 12  highest validation accuracy: 68.1989247311828\...
# 16  highest validation accuracy: 68.1989247311828\...
# 17  highest validation accuracy: 68.1989247311828\...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_URG_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 4           70                   68.199                    89.516129
# 5           78                   68.199                    69.892473
# 6           60                   68.199                    22.580645
# 10          58                   68.199                    48.924731
# 13          22                   68.199                    74.462366
# 15          28                   68.199                    60.215054
#
#                                    performance_string  \
# 4   highest validation accuracy: 68.1989247311828\...
# 5   highest validation accuracy: 68.1989247311828\...
# 6   highest validation accuracy: 68.1989247311828\...
# 10  highest validation accuracy: 68.1989247311828\...
# 13  highest validation accuracy: 68.1989247311828\...
# 15  highest validation accuracy: 68.1989247311828\...
#
#                                     experiment_folder
# ...

# %%
print('RF, Binary, Average Accuracy:')
print('WHITE: {}'.format(np.mean(scenario_21vs4_WHITE_df.corresponding_test_accuracy.values)))
print('ASIAN: {}'.format(np.mean(scenario_21vs4_ASIAN_df.corresponding_test_accuracy.values)))
print('URG: {}'.format(np.mean(scenario_21vs4_URG_df.corresponding_test_accuracy.values)))
# Out:
# RF, Binary, Average Accuracy:
# WHITE: 61.917562724014346
# ASIAN: 52.73297491039427
# URG: 60.931899641577054

# %% [markdown]
# ### seed5

# %%
root_path = '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_models/WhiteSubset/EEGNet/binary/'

# %%
scenario_21vs6_summary_path = '21vs6/seed5_summary'

# %%
scenario_21vs4_df = pd.read_csv(os.path.join(root_path, scenario_21vs6_summary_path, 'AllSubjects_summary.csv'))

# %%
scenario_21vs4_WHITE_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(WHITE_list)]
scenario_21vs4_ASIAN_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(ASIAN_list)]
scenario_21vs4_URG_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(URG_list)]

# %%
scenario_21vs4_WHITE_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 0           69                   72.285                    65.322581
# 1           34                   72.285                    77.150538
# 8           97                   72.285                    76.075269
# 11          86                   72.285                    72.311828
# 14          20                   72.285                    66.666667
# 16          79                   72.285                    68.548387
#
#                                    performance_string  \
# 0   highest validation accuracy: 72.28494623655915...
# 1   highest validation accuracy: 72.28494623655915...
# 8   highest validation accuracy: 72.28494623655915...
# 11  highest validation accuracy: 72.28494623655915...
# 14  highest validation accuracy: 72.28494623655915...
# 16  highest validation accuracy: 72.28494623655915...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_ASIAN_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 2            7                   72.285                    63.172043
# 3           56                   72.285                    80.913978
# 6           43                   72.285                    94.354839
# 7           49                   72.285                    55.913978
# 12          57                   72.285                    73.387097
# 17          61                   72.285                    63.709677
#
#                                    performance_string  \
# 2   highest validation accuracy: 72.28494623655915...
# 3   highest validation accuracy: 72.28494623655915...
# 6   highest validation accuracy: 72.28494623655915...
# 7   highest validation accuracy: 72.28494623655915...
# 12  highest validation accuracy: 72.28494623655915...
# 17  highest validation accuracy: 72.28494623655915...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_URG_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 4           70                   72.285                    62.096774
# 5           78                   72.285                    86.559140
# 9           60                   72.285                    40.322581
# 10          58                   72.285                    58.870968
# 13          22                   72.285                    64.784946
# 15          28                   72.285                    58.064516
#
#                                    performance_string  \
# 4   highest validation accuracy: 72.28494623655915...
# 5   highest validation accuracy: 72.28494623655915...
# 9   highest validation accuracy: 72.28494623655915...
# 10  highest validation accuracy: 72.28494623655915...
# 13  highest validation accuracy: 72.28494623655915...
# 15  highest validation accuracy: 72.28494623655915...
#
#                                     experiment_folder
# ...

# %%
print('RF, Binary, Average Accuracy:')
print('WHITE: {}'.format(np.mean(scenario_21vs4_WHITE_df.corresponding_test_accuracy.values)))
print('ASIAN: {}'.format(np.mean(scenario_21vs4_ASIAN_df.corresponding_test_accuracy.values)))
print('URG: {}'.format(np.mean(scenario_21vs4_URG_df.corresponding_test_accuracy.values)))
# Out:
# RF, Binary, Average Accuracy:
# WHITE: 71.01254480286738
# ASIAN: 71.90860215053763
# URG: 61.783154121863795

# %% [markdown]
# ### seed7

# %%
root_path = '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_models/WhiteSubset/EEGNet/binary/'

# %%
scenario_21vs6_summary_path = '21vs6/seed7_summary'

# %%
scenario_21vs4_df = pd.read_csv(os.path.join(root_path, scenario_21vs6_summary_path, 'AllSubjects_summary.csv'))

# %%
scenario_21vs4_WHITE_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(WHITE_list)]
scenario_21vs4_ASIAN_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(ASIAN_list)]
scenario_21vs4_URG_df = scenario_21vs4_df.loc[scenario_21vs4_df['subject_id'].isin(URG_list)]

# %%
scenario_21vs4_WHITE_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 0           69                   76.505                    86.827957
# 1           34                   76.505                    55.376344
# 2           85                   76.505                    98.118280
# 9           31                   76.505                    26.075269
# 11          32                   76.505                    69.086022
# 12          86                   76.505                    50.000000
#
#                                    performance_string  \
# 0   highest validation accuracy: 76.50537634408602...
# 1   highest validation accuracy: 76.50537634408602...
# 2   highest validation accuracy: 76.50537634408602...
# 9   highest validation accuracy: 76.50537634408602...
# 11  highest validation accuracy: 76.50537634408602...
# 12  highest validation accuracy: 76.50537634408602...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_ASIAN_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 3           56                   76.505                    93.817204
# 4           51                   76.505                    85.483871
# 7           65                   76.505                    70.967742
# 13          52                   76.505                    54.032258
# 15          25                   76.505                    64.247312
# 17          44                   76.505                    55.107527
#
#                                    performance_string  \
# 3   highest validation accuracy: 76.50537634408602...
# 4   highest validation accuracy: 76.50537634408602...
# 7   highest validation accuracy: 76.50537634408602...
# 13  highest validation accuracy: 76.50537634408602...
# 15  highest validation accuracy: 76.50537634408602...
# 17  highest validation accuracy: 76.50537634408602...
#
#                                     experiment_folder
# ...

# %%
scenario_21vs4_URG_df
# Out:
#     subject_id  max_validation_accuracy  corresponding_test_accuracy  \
# 5           70                   76.505                    68.817204
# 6           78                   76.505                    95.967742
# 8           60                   76.505                    44.892473
# 10          58                   76.505                    47.580645
# 14          22                   76.505                    71.505376
# 16          28                   76.505                    57.795699
#
#                                    performance_string  \
# 5   highest validation accuracy: 76.50537634408602...
# 6   highest validation accuracy: 76.50537634408602...
# 8   highest validation accuracy: 76.50537634408602...
# 10  highest validation accuracy: 76.50537634408602...
# 14  highest validation accuracy: 76.50537634408602...
# 16  highest validation accuracy: 76.50537634408602...
#
#                                     experiment_folder
# ...

# %%
print('RF, Binary, Average Accuracy:')
print('WHITE: {}'.format(np.mean(scenario_21vs4_WHITE_df.corresponding_test_accuracy.values)))
print('ASIAN: {}'.format(np.mean(scenario_21vs4_ASIAN_df.corresponding_test_accuracy.values)))
print('URG: {}'.format(np.mean(scenario_21vs4_URG_df.corresponding_test_accuracy.values)))
# Out:
# RF, Binary, Average Accuracy:
# WHITE: 64.24731182795699
# ASIAN: 70.60931899641578
# URG: 64.42652329749104
