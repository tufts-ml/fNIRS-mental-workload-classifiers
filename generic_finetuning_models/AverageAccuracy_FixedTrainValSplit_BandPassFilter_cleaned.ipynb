# %%
import numpy as np
import pandas as pd
import os
import sys

# %% [markdown]
# ### DeepConvNet, 5050, fine tuned for 300epoch, seed1

# %% [markdown]
# lrs = [0.001, 0.003, 0.01, 0.03, 0.1]
# dropouts = [0.25, 0.5, 0.75]

# %%
root_path = '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/DeepConvNet/binary/'

# %%
scenario_64vs4_train100_summary_path = 'train_100/64vs4_summary'
scenario_64vs4_train50_summary_path = 'train_50/64vs4_summary'

# %%
DCN_scenario_64vs4_train100_df = pd.read_csv(os.path.join(root_path, scenario_64vs4_train100_summary_path, 'AllSubjects_summary.csv'))
DCN_scenario_64vs4_train50_df = pd.read_csv(os.path.join(root_path, scenario_64vs4_train50_summary_path, 'AllSubjects_summary.csv'))

# %%
print('DeepConvNet, Binary, Average Accuracy:')
print('scenario_64vs4_train100: {}'.format(np.mean(DCN_scenario_64vs4_train100_df.corresponding_test_accuracy.values)))
print('scenario_64vs4_train50: {}'.format(np.mean(DCN_scenario_64vs4_train50_df.corresponding_test_accuracy.values)))
# Out:
# DeepConvNet, Binary, Average Accuracy:
# scenario_64vs4_train100: 60.70524984187223
# scenario_64vs4_train50: 57.07621758380772

# %%
DCN_scenario_64vs4_train100_df
# Out:
#     subject_id        bucket  max_validation_accuracy  \
# 0           56   TestBucket1                   73.118
# 1           72   TestBucket1                   82.796
# 2           86   TestBucket1                   96.774
# 3           79   TestBucket1                   50.000
# 4           82   TestBucket2                   83.871
# ..         ...           ...                      ...
# 63          35  TestBucket16                   65.591
# 64          21  TestBucket17                  100.000
# 65          60  TestBucket17                  100.000
# 66          29  TestBucket17                   90.323
# 67          25  TestBucket17                   77.419
#
#     corresponding_test_accuracy  \
# 0                     77.150538
# 1                     56.451613
# 2                     50.000000
# 3                     69.892473
# 4                     32.258065
# ..                          ...
# 63                    62.096774
# 64                    30.913978
# ...

# %%
DCN_scenario_64vs4_train100_df.sort_values(by=['max_validation_accuracy'], ascending=False)
# Out:
#     subject_id        bucket  max_validation_accuracy  \
# 54          74  TestBucket14                  100.000
# 12          62   TestBucket4                  100.000
# 47          20  TestBucket12                  100.000
# 45           5  TestBucket12                  100.000
# 52          46  TestBucket14                  100.000
# ..         ...           ...                      ...
# 10          14   TestBucket3                   60.215
# 3           79   TestBucket1                   50.000
# 49          78  TestBucket13                   50.000
# 43          44  TestBucket11                   50.000
# 19          42   TestBucket5                   50.000
#
#     corresponding_test_accuracy  \
# 54                    58.064516
# 12                    68.817204
# 47                    59.139785
# 45                    94.892473
# 52                    86.559140
# ..                          ...
# 10                    77.956989
# 3                     69.892473
# ...

# %%
DCN_scenario_64vs4_train100_df.experiment_folder.values
# Out:
# array(['/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/DeepConvNet/binary/train_100/64vs4/TestBucket1/56/lr0.03_dropout0.25',
#        '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/DeepConvNet/binary/train_100/64vs4/TestBucket1/72/lr0.1_dropout0.5',
#        '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/DeepConvNet/binary/train_100/64vs4/TestBucket1/86/lr0.01_dropout0.75',
#        '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/DeepConvNet/binary/train_100/64vs4/TestBucket1/79/lr0.03_dropout0.75',
#        '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/DeepConvNet/binary/train_100/64vs4/TestBucket2/82/lr0.1_dropout0.25',
# ...

# %% [markdown]
# ### EEGNet, 5050, fine tuned for 300epoch, seed1

# %% [markdown]
# lrs = [0.001, 0.003, 0.01, 0.03, 0.1]
# dropouts = [0.25, 0.5, 0.75]

# %%
root_path = '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/EEGNet/binary/'

# %%
scenario_64vs4_train100_summary_path = 'train_100/64vs4_summary'
scenario_64vs4_train50_summary_path = 'train_50/64vs4_summary'

# %%
EEGNet_scenario_64vs4_train100_df = pd.read_csv(os.path.join(root_path, scenario_64vs4_train100_summary_path, 'AllSubjects_summary.csv'))
EEGNet_scenario_64vs4_train50_df = pd.read_csv(os.path.join(root_path, scenario_64vs4_train50_summary_path, 'AllSubjects_summary.csv'))

# %%
print('DeepConvNet, Binary, Average Accuracy:')
print('scenario_64vs4_train100: {}'.format(np.mean(EEGNet_scenario_64vs4_train100_df.corresponding_test_accuracy.values)))
print('scenario_64vs4_train50: {}'.format(np.mean(EEGNet_scenario_64vs4_train50_df.corresponding_test_accuracy.values)))
# Out:
# DeepConvNet, Binary, Average Accuracy:
# scenario_64vs4_train100: 63.009962049335854
# scenario_64vs4_train50: 58.02893738140417

# %%
EEGNet_scenario_64vs4_train100_df.sort_values(by=['corresponding_test_accuracy'])
# Out:
#     subject_id        bucket  max_validation_accuracy  \
# 53          97  TestBucket14                   77.957
# 51          28  TestBucket13                  100.000
# 24          27   TestBucket7                   52.688
# 37          31  TestBucket10                   88.710
# 20          70   TestBucket6                  100.000
# ..         ...           ...                      ...
# 5           55   TestBucket2                  100.000
# 42          64  TestBucket11                  100.000
# 30          45   TestBucket8                  100.000
# 44          49  TestBucket12                   92.473
# 27          76   TestBucket7                  100.000
#
#     corresponding_test_accuracy  \
# 53                     6.451613
# 51                    26.612903
# 24                    28.494624
# 37                    32.258065
# 20                    34.139785
# ..                          ...
# 5                     94.892473
# 42                    96.236559
# ...

# %%
EEGNet_scenario_64vs4_train100_df.sort_values(by=['corresponding_test_accuracy']).experiment_folder.values
# Out:
# array(['/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/EEGNet/binary/train_100/64vs4/TestBucket14/97/lr0.001_dropout0.5',
#        '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/EEGNet/binary/train_100/64vs4/TestBucket13/28/lr0.1_dropout0.75',
#        '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/EEGNet/binary/train_100/64vs4/TestBucket7/27/lr0.001_dropout0.5',
#        '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/EEGNet/binary/train_100/64vs4/TestBucket10/31/lr0.001_dropout0.25',
#        '/cluster/tufts/hugheslab/zhuang12/HCI/NuripsDataSet2021/experiments/FixedTrainValSplit_generic_finetuning_models/EEGNet/binary/train_100/64vs4/TestBucket6/70/lr0.01_dropout0.75',
# ...
